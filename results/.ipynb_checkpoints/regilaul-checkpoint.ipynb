# %%
#the directory of song files
lyrics = "/Users/sarah/qp_final/lyrics/"
#the audio file and textgrid extension
regilaul = "/Users/sarah/qp_final/results/data_421/"
# waves = "/Users/sarah/qp_final/results/data_421/" 
import os
from os.path import join 
import codecs 
import parselmouth
from parselmouth import Sound 
import praatio
import praatio.textgrid
import nltk
import estnltk

class Song:
    
    grid = []
    wave = "audio.wav"

  
    def ___init___(self, tgs, waves):  
        self.tgs = tgs
        self.waves = waves
    
    def getSongs(regilaul):
       for fn in os.listdir(regilaul):
        name, ext = fn.split()
        if ext == '.TextGrid': 
            # tmp = open(os.path.join(tgs,fn),'r')
            grid = fn.openTextgrid(os.path.join(tgs,fn), True)
            wave = Sound(open(join(tgs,join(name,'.wav'))))
            entry = Song(grid,wave)

        

    def getLyrics(self, lyrics):
        songs = {}
        for item in os.listdir(lyrics):
            
            if item.endswith('.txt'):
                name = item.strip('.txt')
                songLines = []
                with open(join(lyrics,item),'r') as t:
                    songLines.append(t.readlines())
                songs.update({name:songLines})
                self.name = name
        return songs
    
    # def getAnnotation(self,tgs):
    #     grids = {}
    #     for item in os.listdir(tgs):

    #         if item.endswith('.TextGrid'):
    #             name = item.strip('.TextGrid')
    #             me = textgrid.openTextgrid(join(tgs,item),True,"warning")
    #             meDict = me.tierDict
    #             grids.update({name:meDict})
    #     return grids
            
                    

                



# y = Songs()
# y.getLyrics(lyrics)
# y.getAnnotation(tgs=tgs)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /var/folders/s2/hj078vmj60j2qr4wwsp2bgvm0000gp/T/ipykernel_95398/1333298935.py in <module>
#      12 import praatio.textgrid
#      13 import nltk
# ---> 14 import estnltk
#      15
#      16 class Song:
#
# ~/miniconda3/envs/soundmines/lib/python3.9/site-packages/estnltk/__init__.py in <module>
#      13 from estnltk_core.layer.enveloping_span import EnvelopingSpan
#      14 from estnltk_core.layer.span_list import SpanList
# ---> 15 from estnltk_core.layer.layer import Layer
#      16
#      17 from estnltk_core.taggers.tagger import Tagger
#
# ~/miniconda3/envs/soundmines/lib/python3.9/site-packages/estnltk_core/layer/layer.py in <module>
#       9 from copy import deepcopy
#      10
# ---> 11 from estnltk_core import BaseSpan, ElementaryBaseSpan, EnvelopingBaseSpan
#      12 from estnltk_core import Span, Annotation
# ...

# %%
class WordWithAudio:
    def ___init___(self):
        pass
    def filedids(self): 
        # return [name for name in os.listdir(self)]
        pass

# %%
#FreqDist inherits counter class
#inheritance
songs = "/Users/sarah/qp_final/results/data_421/"
import os 
from praatio import textgrid
import parselmouth
from parselmouth import Sound
class Songs: 
    grid = []
    wave = "parselmouth.Sound"
    
    def ___init___(self, grid, wave):
        self.grid = grid
        self.wave = wave
    def makeSongs(songs):
        for fn in os.listdir(songs):
            name, ext = fn.split('.')
            if ext == 'TextGrid': 
                # tmp = open(os.path.join(tgs,fn),'r')
                Songs.grid = textgrid.openTextgrid(os.path.join(songs,fn), True)
                Songs.wave = Sound(join(songs,name+'.wav'))
                return Songs
                
  

        




song = Songs.makeSongs(songs)

#need syllable index/tokenization in lines

# %%
import pandas as pd 
song = Songs.makeSongs(songs)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/s2/hj078vmj60j2qr4wwsp2bgvm0000gp/T/ipykernel_95398/13623076.py in <module>
#       3
#       4
# ----> 5 song_df = pd.CategoricalDtype(song)
#
# ~/miniconda3/envs/soundmines/lib/python3.9/site-packages/pandas/core/dtypes/dtypes.py in __init__(self, categories, ordered)
#     181
#     182     def __init__(self, categories=None, ordered: Ordered = False):
# --> 183         self._finalize(categories, ordered, fastpath=False)
#     184
#     185     @classmethod
#
# ~/miniconda3/envs/soundmines/lib/python3.9/site-packages/pandas/core/dtypes/dtypes.py in _finalize(self, categories, ordered, fastpath)
#     335
#     336         if categories is not None:
# --> 337             categories = self.validate_categories(categories, fastpath=fastpath)
#     338
#     339         self._categories = categories
#
# ...

# %%
# import pandas as pd
# from collections import defaultdict
# from collections import ChainMap
# import nltk 


# # tgD = y.getAnnotation(tgs)
# lyrDic = y.getLyrics(lyrics)

# # yDict = {k:v for d in (tgD,lyrDic) for k,v in d.items()}

# # y_df = pd.DataFrame(yDict)

# #print(yDict)
# # y_df

# #song_df = pd.DataFrame[y.getAnnotation()]

# %%
# lyric_df = pd.DataFrame(lyrDic)
# lyric_df.tail()
# lyric_df["words"] =
# Out:
#                                                  065  \
# 0  [Uidaruu, raidaraa,\n, uidaruu,\n, pandi mind ...
#
#                                                   77  \
# 0  [Kelle õuese õunapuu?\n, Meie õuese õunapuu.\n...
#
#                                                   94  \
# 0  [Kuningas, kuningas,\n, miks sa mullu meile ei...
#
#                                                  009  \
# 0  [Lõpe, lõpe, linakene,\n, üles,\n, kui sa-i lõ...
#
#                                                   55  \
# 0  [Laula, laula, suukkene,\n, liigu, linnu keele...
#
#                                                   41  \
# 0  [Ui-sui-sui-sui sun´niman´ni,\n, sun´niman´nis...
#
#                                                   69  \
# 0  [Oh me vaesed öösed orjad,\n, kas´ke,\n, öösed...
#
#                                                  018  \
# 0  [Laske sissi kadrisandi,\n, katrisanti,\n, Las...
#
#                                                   92
# ...
